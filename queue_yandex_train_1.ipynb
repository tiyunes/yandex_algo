# %%
lines = []
while True:
    line = input()
    if line and line != "exit":
        lines.append(line)
    elif line == "exit":
      lines.append(line)
      break
    else:
      break
request = '\n'.join(lines)
# Out:
# push 3
# push 14
# size
# clear
# push 1
# front
# push 2
# front
# pop
# size
# pop
# size
# exit

# %%
queue = []
for line in request.splitlines():
  list_request = line.split()
  if (list_request[0] == 'push'):
    queue.append(list_request[1])
    print("ok")
  elif (list_request[0] == 'pop'):
    if (len(queue) == 0):
      print("error")
    else:
      x = queue.pop(0)
      print(x)
  elif (list_request[0] == 'front'):
    if (len(queue) == 0):
      print("error")
    else:
      print(queue[0])
  elif (list_request[0] == 'size'): 
    print(len(queue))
  elif (list_request[0] == 'clear'):
    queue.clear()
    print("ok")
  elif (list_request[0] == 'exit'):
    # flag = 0
    print("bye") 
    break
# Out:
# ok
# ok
# 2
# ok
# ok
# 1
# ok
# 1
# 1
# 1
# 2
# 0
# bye
