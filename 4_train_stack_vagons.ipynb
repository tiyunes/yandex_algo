# %%
N = int(input())
vagons = []
input_string = input()
string_to_list = input_string.split()
for i in range(N):
  vagons.append(int(string_to_list[i]))
# Out:
# 3
# 2 3 1

# %%
stack = []
way2 = []
k = 1
flag = 1
for vagon in vagons:
  if (vagon == k):
    way2.append(vagon)
    k += 1
  elif (len(stack) > 0 and stack[-1] == k):
    while (len(stack) > 0 and stack[-1] == k):
      way2.append(stack.pop())
      k += 1
    stack.append(vagon)
  else:
    stack.append(vagon)

while (True):
  if (len(stack) > 0 and stack[-1] == k):
    way2.append(stack.pop())
    k += 1
  elif (len(stack) > 0 and stack[-1] != k):
    print("NO")
    flag = 0
    break
  elif (len(stack) == 0):
    break

if (flag == 1):
  print("YES")

  # print(vagon, ": ", stack)
  # print(vagon, ": ", way2)
# while (len(stack) > 0):
#   way2.append(stack.pop())

# vagonsNumber = N
# flag = 1
# for vagon in way2:
#   if (vagon != vagonsNumber):
#     print("NO")
#     flag = 0
#     break
#   vagonsNumber -= 1

# if (flag == 1):
#   print("YES")
# Out:
# NO
